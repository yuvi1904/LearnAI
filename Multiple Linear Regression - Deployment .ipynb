# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_Multiplelinear.sav",'rb'))
result=loaded_model.predict([[123,456,789,112,134,1]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[41928.1268043]])
